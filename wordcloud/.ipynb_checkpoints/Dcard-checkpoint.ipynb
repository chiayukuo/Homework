# %%
from selenium import webdriver
from pyquery import PyQuery as pq
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://www.dcard.tw/topics/{}'.format('感情'))
html = driver.find_element_by_css_selector("*").get_attribute("outerHTML")
doc = pq(html)

# %%
doc

# %% [markdown]
# ## 滑動網頁數次

# %%
import time

for i in range(40):
    js="var action=document.documentElement.scrollTop=10000000"
    driver.execute_script(js)
    time.sleep(2)

# %% [markdown]
# # 爬取熱門文章標題

# %%
title = []

for i in range(250):  #到時候看怎麼把range變大
    html = driver.find_element_by_css_selector("*").get_attribute("outerHTML")
    doc = pq(html)
    info=doc('.sc-1rp9nay-4.iylEpa')     
    for data in info:
        title.append(doc(data).text())

# %%
title
# Out:
# ['為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  '男友猜不透女友的內心戲',
#  '#圖 五年了，為什麼還愛我',
#  '給分手的人',
#  '情侶一起洗澡',
#  '浪流連：我愛上一位酒家女',
#  '我在我女朋友面前被硬上了',
#  '回覆:我妹上了我男友',
#  '史上最蝦(醉蝦)的分手理由.......',
#  '愛情跟麵包 我選擇麵包',
#  '《爺奶的愛情》其實妳都記得吧',
#  '那些年，炮仔聲教我們的感情',
#  '情調就是拿來毀掉的（微西施）',
#  '為何很多高材生工程師都沒有對象',
#  '我是不是弄巧成拙了？',
#  '你給我下車！（我的超可愛閃光',
#  '講再多顏值才是重點😌',
#  '#更 直球這麼明顯了 就差一步了……',
#  '如果我不能生怎麼辦？',
#  '我沒有要玩你啦（微西斯',
#  '好想認識胖胖的女生',
#  '女同學閃避屬性點滿 更',
#  '#對不起各位，我是她男友',
#  '「磨合」與「不適合」的不同？',
#  ...]

# %%
len(title)
# Out:
# 5750

# %% [markdown]
# # 製作簡易文字雲

# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator
import jieba
import numpy as np
from collections import Counter

# %%
''.join(title)
# Out:
# '為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五年了，為什麼還愛我給分手的人情侶一起洗澡浪流連：我愛上一位酒家女我在我女朋友面前被硬上了回覆:我妹上了我男友史上最蝦(醉蝦)的分手理由.......愛情跟麵包 我選擇麵包《爺奶的愛情》其實妳都記得吧那些年，炮仔聲教我們的感情情調就是拿來毀掉的（微西施）為何很多高材生工程師都沒有對象我是不是弄巧成拙了？你給我下車！（我的超可愛閃光講再多顏值才是重點😌#更 直球這麼明顯了 就差一步了……如果我不能生怎麼辦？我沒有要玩你啦（微西斯好想認識胖胖的女生女同學閃避屬性點滿 更#對不起各位，我是她男友「磨合」與「不適合」的不同？男友猜不透女友的內心戲#圖 五 ...

# %%
#設定字典
jieba.set_dictionary('dict.txt.big.txt')
