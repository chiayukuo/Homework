# %%
import pandas as pd

# %%
df = pd.read_csv("108_3.csv", thousands=",")   #去除千分位的逗號

# %%
df
# Out:
#      公司名稱  公司代號  營業收入(百萬元)  毛利率(%)  營業利益率(%)  稅前純益率(%)  稅後純益率(%)
# 0      亞泥  1102   66206.88   28.86     24.47     32.51     25.58
# 1      環泥  1104    3551.36   10.30      1.71     20.54     19.81
# 2      信大  1109    5620.43   32.88     26.61     26.38     17.85
# 3      味全  1201   15431.85   31.12      3.22     10.53      8.37
# 4      大成  1210   56773.25   15.27      4.61      4.93      3.85
# ..    ...   ...        ...     ...       ...       ...       ...
# 450    信義  9940    9304.70   31.20     17.57     18.43     10.91
# 451    茂順  9942    2252.55   34.12     19.09     19.82     14.31
# 452    新麗  9944    2237.10   24.14      3.18      2.42      0.73
# 453  三發地產  9946    3930.37   40.88     32.90     32.61     32.47
# 454   世紀鋼  9958    1427.30   10.29     -2.17     42.90     40.42
#
# [455 rows x 7 columns]

# %% [markdown]
# ### 篩出條件符合的股票

# %%
cond1 = df['毛利率(%)'] > 30
cond2 = df['營業利益率(%)'] > 30

df[cond1 & cond2]
# Out:
#        公司名稱  公司代號  營業收入(百萬元)  毛利率(%)  營業利益率(%)  稅前純益率(%)  稅後純益率(%)
# 113      川湖  2059    3495.46   52.97     40.02     46.73     35.49
# 123      為升  2231    3040.72   54.41     33.90     34.62     28.09
# 218    台灣高鐵  2633   35307.60   46.09     43.63     16.98     17.42
# 232      匯僑  2904     386.31   46.93     33.62     32.84     26.04
# 236   鼎固-KY  2923    4346.51   50.08     32.90     40.21    208.36
# 259      和鑫  3049    3279.23   36.69     30.04     28.11     23.90
# 289      牧德  3563    2093.63   66.14     45.55     46.25     37.30
# 306      旭富  4119    1835.79   41.67     31.23     32.96     26.23
# 307   麗豐-KY  4137    3721.34   84.77     35.27     38.89     28.35
# 344      祥碩  5269    2745.49   49.75     31.03     31.74     26.38
# 353      長虹  5534    6417.90   40.23     35.19     37.08     33.75
# 354     遠雄港  5607    1815.76   65.19     48.60     44.81     35.07
# 369     大豐電  6184    1508.81   48.10     30.79     30.64     25.78
# ...

# %% [markdown]
# ### 直方圖

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(10, 6))
df['毛利率(%)'].hist(bins=range(-100,100))
plt.show()
